# %% [markdown]
# ## book feature k-means

# %%
import pandas as pd
import numpy as np
import os

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()
from sklearn.preprocessing import LabelEncoder
encoder = LabelEncoder()

# %%
os.getcwd()
# Out:
# 'C:\\python\\YES24\\2020-06-10'

# %%
os.chdir('C:\\python\\YES24\\2020-06-10'+'/m3')

# %%
book = pd.read_csv('book_feature_product_label.csv')

# %%
book
# Out:
#         product_id  category_id  published  book_price  maker_label  best200  \
# 0         51205670          8.0          3           0         4510        0
# 1         51205708          3.0          3           2         2439        0
# 2         51205718          3.0          3           2         2439        0
# 3         51205795          8.0          3           0         1976        0
# 4         51205801          8.0          3           0         1976        0
# ...            ...          ...        ...         ...          ...      ...
# 284844    85352665          1.0          1           3         4865        0
# 284845    85353942         11.0          1           3          397        0
# 284846    85354052          1.0          1           3          887        0
# 284847    85354327         27.0          1           1         5677        0
# 284848    85354780          1.0          1           3         6875        0
#
#         bestcat24
# 0               0
# 1               0
# 2               0
# 3               0
# 4               0
# ...           ...
# 284844          0
# 284845          0
# 284846          0
# 284847          0
# 284848          0
#
# [284849 rows x 7 columns]

# %%
user = pd.read_csv('(나이)accounts_age_0623.csv')

# %%
user.drop(columns=user.columns[0],inplace=True)

# %%
user
# Out:
#          account_id  gender   age  g_age                           address  \
# 0            102600     0.0  50.0    4.0         경상북도 포항시 남구 지곡동 효자그린1차아파트
# 1            103417     0.0  40.0    3.0                     경기 부천시 원미 심곡동
# 2            105247     1.0  59.0    5.0          광주광역시 북구 일곡동 816-3 동아아파트
# 3            109061     0.0  59.0    5.0                강원 동해시 천곡동 센트로빌아파트
# 4            109217     0.0  46.0    4.0        경기 수원시 영통구 영통1동 황골마을1단지아파트
# ...             ...     ...   ...    ...                               ...
# 1670270    16983289     1.0  48.0    4.0        경기도 안성시 공도읍 용두리 753 산수화아파트
# 1670271    16983447     1.0  32.0    3.0  인천광역시 미추홀구 도화동 1008 e편한세상도화6-2단지
# 1670272    16983639     0.0  32.0    3.0             충청남도 당진시 석문면 통정리 65-3
# 1670273    16983644     1.0  16.0    1.0        경기도 시흥시 정왕동 2483 시흥배곧에스케이뷰
# 1670274    16984035     1.0  25.0    2.0        인천광역시 계양구 작전동 857-19 영흥아파트
#
#          address_is           last_login
# 0                 1  2020-06-09 10:54:54
# 1                 0  2020-05-12 14:57:49
# 2                 1  2020-01-20 05:09:15
# 3                 1  2020-03-13 10:16:41
# 4                 0  2020-03-09 11:32:04
# ...             ...                  ...
# 1670270           0  2020-06-07 17:03:35
# 1670271           1  2020-06-07 20:09:03
# 1670272           1  2020-06-08 00:10:53
# 1670273           0  2020-06-09 00:07:42
# 1670274           1  2020-06-08 06:22:51
#
# [1670275 rows x 7 columns]

# %%
dummies = pd.get_dummies(user['g_age'],prefix='age')

# %%
user_new = pd.concat([user,dummies],axis=1)

# %%
user_new
# Out:
#          account_id  gender   age  g_age                           address  \
# 0            102600     0.0  50.0    4.0         경상북도 포항시 남구 지곡동 효자그린1차아파트
# 1            103417     0.0  40.0    3.0                     경기 부천시 원미 심곡동
# 2            105247     1.0  59.0    5.0          광주광역시 북구 일곡동 816-3 동아아파트
# 3            109061     0.0  59.0    5.0                강원 동해시 천곡동 센트로빌아파트
# 4            109217     0.0  46.0    4.0        경기 수원시 영통구 영통1동 황골마을1단지아파트
# ...             ...     ...   ...    ...                               ...
# 1670270    16983289     1.0  48.0    4.0        경기도 안성시 공도읍 용두리 753 산수화아파트
# 1670271    16983447     1.0  32.0    3.0  인천광역시 미추홀구 도화동 1008 e편한세상도화6-2단지
# 1670272    16983639     0.0  32.0    3.0             충청남도 당진시 석문면 통정리 65-3
# 1670273    16983644     1.0  16.0    1.0        경기도 시흥시 정왕동 2483 시흥배곧에스케이뷰
# 1670274    16984035     1.0  25.0    2.0        인천광역시 계양구 작전동 857-19 영흥아파트
#
#          address_is           last_login  age_0.0  age_1.0  age_2.0  age_3.0  \
# 0                 1  2020-06-09 10:54:54        0        0        0        0
# 1                 0  2020-05-12 14:57:49        0        0        0        1
# 2                 1  2020-01-20 05:09:15        0        0        0        0
# 3                 1  2020-03-13 10:16:41        0        0        0        0
# 4                 0  2020-03-09 11:32:04        0        0        0        0
# ...             ...                  ...      ...      ...      ...      ...
# 1670270           0  2020-06-07 17:03:35        0        0        0        0
# 1670271           1  2020-06-07 20:09:03        0        0        0        1
# 1670272           1  2020-06-08 00:10:53        0        0        0        1
# 1670273           0  2020-06-09 00:07:42        0        1        0        0
# 1670274           1  2020-06-08 06:22:51        0        0        1        0
#
#          age_4.0  age_5.0  age_6.0
# 0              1        0        0
# 1              0        0        0
# 2              0        1        0
# 3              0        1        0
# 4              1        0        0
# ...          ...      ...      ...
# 1670270        1        0        0
# 1670271        0        0        0
# 1670272        0        0        0
# 1670273        0        0        0
# 1670274        0        0        0
#
# [1670275 rows x 14 columns]

# %%
click = pd.read_csv("clicks_refined_train_0625.csv")

# %%
click.drop(columns=click.columns[0],inplace=True)

# %%
click_user = pd.merge(click, user, on='account_id',how='left')
# Out:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# <ipython-input-31-6d1a2d8ddcd0> in <module>
# ----> 1 click_user = pd.merge(click, user, on='account_id',how='left')
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\reshape\merge.py in merge(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#      86         validate=validate,
#      87     )
# ---> 88     return op.get_result()
#      89
#      90
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\reshape\merge.py in get_result(self)
#     657             axes=[llabels.append(rlabels), join_index],
#     658             concat_axis=0,
# --> 659             copy=self.copy,
#     660         )
#     661
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\internals\managers.py in concatenate_block_managers(mgrs_indexers, axes, concat_axis, copy)
#    2020         else:
#    2021             b = make_block(
# -> 2022                 concatenate_join_units(join_units, concat_axis, copy=copy),
#    2023                 placement=placement,
#    2024             )
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\internals\concat.py in concatenate_join_units(join_units, concat_axis, copy)
#     246     to_concat = [
#     247         ju.get_reindexed_values(empty_dtype=empty_dtype, upcasted_na=upcasted_na)
# --> 248         for ju in join_units
#     249     ]
#     250
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\internals\concat.py in <listcomp>(.0)
#     246     to_concat = [
#     247         ju.get_reindexed_values(empty_dtype=empty_dtype, upcasted_na=upcasted_na)
# --> 248         for ju in join_units
#     249     ]
#     250
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\internals\concat.py in get_reindexed_values(self, empty_dtype, upcasted_na)
#     229         else:
#     230             for ax, indexer in self.indexers.items():
# --> 231                 values = algos.take_nd(values, indexer, axis=ax, fill_value=fill_value)
#     232
#     233         return values
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\algorithms.py in take_nd(arr, indexer, axis, out, fill_value, allow_fill)
#    1655             out = np.empty(out_shape, dtype=dtype, order="F")
#    1656         else:
# -> 1657             out = np.empty(out_shape, dtype=dtype)
#    1658
#    1659     func = _get_take_nd_function(
#
# MemoryError: Unable to allocate 589. MiB for an array with shape (3, 25724903) and data type int64
